# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# # WELCOME!

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# The project consists of 3 parts:
# * First part is related with 'data cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, Dropping useless columns.
# * Second part is related with 'filling data'. It deals with Missing Values. Categorical to numeric transformation is done.
# * Third part is related with 'handling outliers of data' via Visualisation libraries. Some insights are extracted.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
scout_car = pd.read_json ('scout_car.json', lines = True)

# %%
df=scout_car

# %%
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %%
df.head(8).T
# Out:
#                                                                                0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %% [markdown]
# # **km Column**

# %%
df.km  # km column u a baktım 15919 satır
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df.km.isnull().any() # herhangibir null değer var mı diye teyit ettim.
# Out:
# False

# %%
df.km[:5]  # ilk beş km satırına baktım.
# Out:
# 0    56,013 km
# 1    80,000 km
# 2    83,450 km
# 3    73,000 km
# 4    16,200 km
# Name: km, dtype: object

# %%
df.km.str.strip("\"").str.rstrip("km")  # km colonundan sağdaki 'km' ibaresini çıkarttım. Başında sonunda " veya \ şfadesi varsa çıkarttım.
# Out:
# 0        56,013
# 1        80,000
# 2        83,450
# 3        73,000
# 4        16,200
#           ...
# 15914         -
# 15915     9,900
# 15916        15
# 15917        10
# 15918         -
# Name: km, Length: 15919, dtype: object

# %%
df.km.str.strip("\"").str.rstrip("km").str.replace(",", "") # # km ifadesini çıkarttım ve sayıların arasındaki ',' virgül ü çıkarttım.
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#           ...
# 15914        -
# 15915     9900
# 15916       15
# 15917       10
# 15918        -
# Name: km, Length: 15919, dtype: object

# %%
df["Kilometer"]= df.km.str.strip("\"").str.rstrip("km").str.replace(",", "")   # son halini yeni bir Column olarak dataFramenin sonuna ekledim.

# %%
df.Kilometer
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#           ...
# 15914        -
# 15915     9900
# 15916       15
# 15917       10
# 15918        -
# Name: Kilometer, Length: 15919, dtype: object

# %%
df.head(1) # son kısma Kilometer column u  eklendi mi diye kontrol ettim.
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat         km registration         prev_owner  kW     hp  \
# 0  VAT deductible  56,013 km      01/2016  2 previous owners NaN  66 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
#
#                   Warranty Full Service Non-smoking Vehicle null      Make  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []  \nAudi\n
#
#           Model     Offer Number First Registration       Body Color  \
# 0  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]  [\n, Black, \n]
#
# ...

# %% [markdown]
# ## **Paint Color**

# %%
df["Body Color"]
# Out:
# 0        [\n, Black, \n]
# 1          [\n, Red, \n]
# 2        [\n, Black, \n]
# 3        [\n, Brown, \n]
# 4        [\n, Black, \n]
#               ...
# 15914     [\n, Grey, \n]
# 15915     [\n, Grey, \n]
# 15916    [\n, White, \n]
# 15917     [\n, Grey, \n]
# 15918     [\n, Grey, \n]
# Name: Body Color, Length: 15919, dtype: object

# %%
df["Body Color"].isnull().any() # herhangibir null değer var mı diye teyit ettim. Varmış:)
# Out:
# True

# %%
df["Body_Color"]= [item[1] if type(item)==list else item for item in df["Body Color"]]
df["Body_Color"]
# Out:
# 0        Black
# 1          Red
# 2        Black
# 3        Brown
# 4        Black
#          ...
# 15914     Grey
# 15915     Grey
# 15916    White
# 15917     Grey
# 15918     Grey
# Name: Body_Color, Length: 15919, dtype: object

# %%
df["Body_Color"].unique()
# Out:
# array(['Black', 'Red', 'Brown', 'White', 'Grey', 'Silver', 'Blue', nan,
#        'Beige', 'Violet', 'Yellow', 'Green', 'Bronze', 'Orange', 'Gold'],
#       dtype=object)

# %% [markdown]
# # **Paint Type**

# %%
df["Paint Type"]
# Out:
# 0        [\nMetallic\n]
# 1                   NaN
# 2        [\nMetallic\n]
# 3        [\nMetallic\n]
# 4        [\nMetallic\n]
#               ...
# 15914    [\nMetallic\n]
# 15915    [\nMetallic\n]
# 15916               NaN
# 15917               NaN
# 15918    [\nMetallic\n]
# Name: Paint Type, Length: 15919, dtype: object

# %%
df["Paint Type"].isnull().any() # herhangibir null değer var mı diye teyit ettim. Varmış:)
# Out:
# True

# %%
df["Paint Type"].describe()
# Out:
# count              10147
# unique                 3
# top       [\nMetallic\n]
# freq                9794
# Name: Paint Type, dtype: object

# %%
df["Paint_Type"]= [item[0] if type(item)==list else item for item in df["Paint Type"]]
df["Paint_Type"]= df["Paint_Type"].str.strip("\n")
df["Paint_Type"]=df["Paint_Type"].str.lower()
df["Paint_Type"]
# Out:
# 0        metallic
# 1             NaN
# 2        metallic
# 3        metallic
# 4        metallic
#            ...
# 15914    metallic
# 15915    metallic
# 15916         NaN
# 15917         NaN
# 15918    metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df["Paint_Type"].unique()
# Out:
# array(['metallic', nan, 'uni/basic', 'perl effect'], dtype=object)

# %% [markdown]
# ## **Body Color Original**

# %%
df["Body Color Original"]
# Out:
# 0                 [\nMythosschwarz\n]
# 1                                 NaN
# 2        [\nmythosschwarz metallic\n]
# 3                                 NaN
# 4        [\nMythosschwarz Metallic\n]
#                      ...
# 15914              [\nGrigio scuro\n]
# 15915       [\nStahl-Grau Metallic\n]
# 15916               [\narktis-weiß\n]
# 15917                    [\nGrigio\n]
# 15918    [\nTitanium-Grau Metallic\n]
# Name: Body Color Original, Length: 15919, dtype: object

# %%
df["Body_Color_Original"]= [item[0] if type(item)==list else item for item in df["Body Color Original"]]
df["Body_Color_Original"]= df["Body_Color_Original"].str.strip("\n")
df["Body_Color_Original"]=df["Body_Color_Original"].str.lower()
df["Body_Color_Original"]
# Out:
# 0                 mythosschwarz
# 1                           NaN
# 2        mythosschwarz metallic
# 3                           NaN
# 4        mythosschwarz metallic
#                   ...
# 15914              grigio scuro
# 15915       stahl-grau metallic
# 15916               arktis-weiß
# 15917                    grigio
# 15918    titanium-grau metallic
# Name: Body_Color_Original, Length: 15919, dtype: object

# %%
df["Body_Color_Original"]=df["Body_Color_Original"].str.findall("metallic")
df["Body_Color_Original"]
# Out:
# 0                []
# 1               NaN
# 2        [metallic]
# 3               NaN
# 4        [metallic]
#             ...
# 15914            []
# 15915    [metallic]
# 15916            []
# 15917            []
# 15918    [metallic]
# Name: Body_Color_Original, Length: 15919, dtype: object

# %%
df["Body_Color_Original"].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10456/3511810724.py in <module>
# ----> 1 df["Body_Color_Original"].unique()
#
# ~\anaconda3\envs\python_giris\lib\site-packages\pandas\core\series.py in unique(self)
#    1870         Categories (3, object): ['a' < 'b' < 'c']
#    1871         """
# -> 1872         result = super().unique()
#    1873         return result
#    1874
#
# ~\anaconda3\envs\python_giris\lib\site-packages\pandas\core\base.py in unique(self)
#    1045                     result = np.asarray(result)
#    1046         else:
# -> 1047             result = unique1d(values)
#    1048
#    1049         return result
#
# ~\anaconda3\envs\python_giris\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     405
#     406     table = htable(len(values))
# --> 407     uniques = table.unique(values)
# ...

# %% [markdown]
# # **Drive chain**

# %%
df["Drive chain"]

# %%
df["Drive chain"].isnull().any() # herhangibir null değer var mı diye teyit ettim.

# %%
df["Drive_chain"]= [item[0] if type(item)==list else item for item in df["Drive chain"]]
df["Drive_chain"]= df["Drive_chain"].str.strip("\n")
df["Drive_chain"]
# Out:
# 0        front
# 1        front
# 2        front
# 3          NaN
# 4        front
#          ...
# 15914    front
# 15915    front
# 15916    front
# 15917    front
# 15918      4WD
# Name: Drive_chain, Length: 15919, dtype: object

# %%
df["Drive_chain"].unique()
# Out:
# array(['front', nan, '4WD', 'rear'], dtype=object)

# %%
df.head(2)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
#
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# ...

# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %% [markdown]
# # **km Column**

# %%
df["Kilometer"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # **Paint Type**

# %%
df["Paint_Type"].isnull().sum()
# Out:
# 5772

# %% [markdown]
# # **Drive chain**

# %%
df["Drive_chain"].isnull().sum()
# Out:
# 6858

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
